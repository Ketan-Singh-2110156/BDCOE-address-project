# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\DELL\Desktop\Admit SLU Rest world.xlsx")

# %%
df
# Out:
#     Application: Application ID Applicant First Name Applicant Last Name  \
# 0                App ID-4615373              Moukuri               Mohim
# 1                App ID-4620926          Md. Hossain                Khan
# 2                App ID-4682918                Naiem              Mahadi
# 3                App ID-4695373         Siyamul Huda               Kabyo
# 4                App ID-4697239                Rakib               Ahmed
# ..                          ...                  ...                 ...
# 141              App ID-4488642                Akbar       Abdurakhmonov
# 142              App ID-4592097               Otabek       Nurmukhamedov
# 143              App ID-4722969            Sardorjon             Hasanov
# 144              App ID-4492982                Edwin        Muchechetere
# 145              App ID-4687962               Praise                Moyo
#
#                                       Applicant: Major Primary Phone Number  \
# ...

# %%
df.head()
# Out:
#   Application: Application ID Applicant First Name Applicant Last Name  \
# 0              App ID-4615373              Moukuri               Mohim
# 1              App ID-4620926          Md. Hossain                Khan
# 2              App ID-4682918                Naiem              Mahadi
# 3              App ID-4695373         Siyamul Huda               Kabyo
# 4              App ID-4697239                Rakib               Ahmed
#
#                                  Applicant: Major Primary Phone Number  \
# 0                              MBA - Professional           1883982526
# 1                              MBA - Professional           1710844300
# 2                    Supply Chain Management - MS           1554454009
# 3  Master of Science in Cybersecurity (On-Campus)           1890317920
# 4                    Supply Chain Management - MS           1911356577
#
#   Applicant: Date Application Started  \
# 0                           7/14/2022
# ...

# %%
df.shape
# Out:
# (146, 16)

# %%
df.tail()
# Out:
#     Application: Application ID Applicant First Name Applicant Last Name  \
# 141              App ID-4488642                Akbar       Abdurakhmonov
# 142              App ID-4592097               Otabek       Nurmukhamedov
# 143              App ID-4722969            Sardorjon             Hasanov
# 144              App ID-4492982                Edwin        Muchechetere
# 145              App ID-4687962               Praise                Moyo
#
#                                       Applicant: Major Primary Phone Number  \
# 141                       Supply Chain Management - MS            998351785
# 142                   Applied Financial Economics - MS            998044993
# 143                       Supply Chain Management - MS            990540571
# 144     Master of Science in Cybersecurity (On-Campus)            778820923
# 145  Master of Science in Bioinformatics and Comput...         263719220109
#
#     Applicant: Date Application Started  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Application: Application ID          146 non-null    object
#  1   Applicant First Name                 146 non-null    object
#  2   Applicant Last Name                  146 non-null    object
#  3   Applicant: Major                     146 non-null    object
#  4   Primary Phone Number                 146 non-null    object
#  5   Applicant: Date Application Started  146 non-null    object
#  6   Major                                146 non-null    object
#  7   MailingStreet                        146 non-null    object
#  8   Mailing Street 2                     42 non-null     object
#  9   MailingCity                          146 non-null    object
#  10  MailingCountry                       146 non-null    object
# ...

# %%
df.describe()
# Out:
#        Application: Application ID Applicant First Name Applicant Last Name  \
# count                          146                  146                 146
# unique                         146                  138                 142
# top                 App ID-4615373              Michael                Khan
# freq                             1                    3                   3
#
#                         Applicant: Major  Primary Phone Number  \
# count                                146                   146
# unique                                18                   145
# top     Applied Financial Economics - MS             544491668
# freq                                  23                     2
#
#        Applicant: Date Application Started                             Major  \
# count                                  146                               146
# unique                                 106                                18
# ...

# %%
df['MailingStreet']
# Out:
# 0         Road-4 House -621 Section -7 Mirpur Dhaka 1216
# 1                   HOUSE-181-1-C, RAB3, BORO MOGHBAZAR,
# 2      2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,
# 3                           #63 Matikata, Matikata Bazar
# 4                          12/B SAYED AWLAD HOSSAIN LANE
#                              ...
# 141                                      S.Darboza 4b/71
# 142                                           uzbekistan
# 143                                    Khujakhurasan 4/1
# 144                                          House No 53
# 145                                        Stand No. 436
# Name: MailingStreet, Length: 146, dtype: object

# %%
df['MailingCity']
# Out:
# 0              Dhaka
# 1              DHAKA
# 2              Dhaka
# 3              Dhaka
# 4              DHAKA
#            ...
# 141         Tashkent
# 142    tashkent city
# 143      Shakhrisabz
# 144            Gweru
# 145            Gweru
# Name: MailingCity, Length: 146, dtype: object

# %%
df['MailingCountry']
# Out:
# 0      Bangladesh
# 1      Bangladesh
# 2      Bangladesh
# 3      Bangladesh
# 4      Bangladesh
#           ...
# 141    Uzbekistan
# 142    Uzbekistan
# 143    Uzbekistan
# 144      Zimbabwe
# 145      Zimbabwe
# Name: MailingCountry, Length: 146, dtype: object

# %%
df['MailingCountry'].value_counts()
# Out:
# Nigeria                 53
# Ghana                   30
# Pakistan                11
# United States            6
# Nepal                    6
# Bangladesh               5
# Liberia                  4
# Ethiopia                 3
# Uzbekistan               3
# China                    3
# South Korea              3
# Russia                   2
# United Arab Emirates     2
# Taiwan                   2
# Zimbabwe                 2
# Cameroon                 2
# Kenya                    2
# Iran                     1
# Romania                  1
# Botswana                 1
# Uganda                   1
# United Kingdom           1
# Cambodia                 1
# Saudi Arabia             1
# Name: MailingCountry, dtype: int64

# %%
df
# Out:
#     Application: Application ID Applicant First Name Applicant Last Name  \
# 0                App ID-4615373              Moukuri               Mohim
# 1                App ID-4620926          Md. Hossain                Khan
# 2                App ID-4682918                Naiem              Mahadi
# 3                App ID-4695373         Siyamul Huda               Kabyo
# 4                App ID-4697239                Rakib               Ahmed
# ..                          ...                  ...                 ...
# 141              App ID-4488642                Akbar       Abdurakhmonov
# 142              App ID-4592097               Otabek       Nurmukhamedov
# 143              App ID-4722969            Sardorjon             Hasanov
# 144              App ID-4492982                Edwin        Muchechetere
# 145              App ID-4687962               Praise                Moyo
#
#                                       Applicant: Major Primary Phone Number  \
# ...

# %%
new=df.drop(['Application: Application ID', 'Applicant First Name','Applicant Last Name', 'Applicant: Major', 'Primary Phone Number', 'Applicant: Date Application Started', 'Major','Scholarship Value','Applicant: Date Deferred','Admissions Status','Term'], axis=1)

# %%
new
# Out:
#                                          MailingStreet       Mailing Street 2  \
# 0       Road-4 House -621 Section -7 Mirpur Dhaka 1216                    NaN
# 1                 HOUSE-181-1-C, RAB3, BORO MOGHBAZAR,                    NaN
# 2    2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,        Sarulia, Demra,
# 3                         #63 Matikata, Matikata Bazar                    NaN
# 4                        12/B SAYED AWLAD HOSSAIN LANE               ISLAMPUR
# ..                                                 ...                    ...
# 141                                    S.Darboza 4b/71  Shayhantohur district
# 142                                         uzbekistan                    NaN
# 143                                  Khujakhurasan 4/1                    NaN
# 144                                        House No 53   Rivermead Road, Iven
# 145                                      Stand No. 436        436 Mtausi Park
#
# ...

# %%
df['MailingCountry'].value_counts()
# Out:
# Nigeria                 53
# Ghana                   30
# Pakistan                11
# United States            6
# Nepal                    6
# Bangladesh               5
# Liberia                  4
# Ethiopia                 3
# Uzbekistan               3
# China                    3
# South Korea              3
# Russia                   2
# United Arab Emirates     2
# Taiwan                   2
# Zimbabwe                 2
# Cameroon                 2
# Kenya                    2
# Iran                     1
# Romania                  1
# Botswana                 1
# Uganda                   1
# United Kingdom           1
# Cambodia                 1
# Saudi Arabia             1
# Name: MailingCountry, dtype: int64

# %%
new
# Out:
#                                          MailingStreet       Mailing Street 2  \
# 0       Road-4 House -621 Section -7 Mirpur Dhaka 1216                    NaN
# 1                 HOUSE-181-1-C, RAB3, BORO MOGHBAZAR,                    NaN
# 2    2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,        Sarulia, Demra,
# 3                         #63 Matikata, Matikata Bazar                    NaN
# 4                        12/B SAYED AWLAD HOSSAIN LANE               ISLAMPUR
# ..                                                 ...                    ...
# 141                                    S.Darboza 4b/71  Shayhantohur district
# 142                                         uzbekistan                    NaN
# 143                                  Khujakhurasan 4/1                    NaN
# 144                                        House No 53   Rivermead Road, Iven
# 145                                      Stand No. 436        436 Mtausi Park
#
# ...

# %%
new.head()
# Out:
#                                        MailingStreet Mailing Street 2  \
# 0     Road-4 House -621 Section -7 Mirpur Dhaka 1216              NaN
# 1               HOUSE-181-1-C, RAB3, BORO MOGHBAZAR,              NaN
# 2  2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,  Sarulia, Demra,
# 3                       #63 Matikata, Matikata Bazar              NaN
# 4                      12/B SAYED AWLAD HOSSAIN LANE         ISLAMPUR
#
#   MailingCity MailingCountry Applicant: Mailing Zip/Postal Code
# 0       Dhaka     Bangladesh                               1216
# 1       DHAKA     Bangladesh                               1217
# 2       Dhaka     Bangladesh                              1361,
# 3       Dhaka     Bangladesh                               1206
# 4       DHAKA     Bangladesh                               1100

# %%
new.tail()
# Out:
#          MailingStreet       Mailing Street 2    MailingCity MailingCountry  \
# 141    S.Darboza 4b/71  Shayhantohur district       Tashkent     Uzbekistan
# 142         uzbekistan                    NaN  tashkent city     Uzbekistan
# 143  Khujakhurasan 4/1                    NaN    Shakhrisabz     Uzbekistan
# 144        House No 53   Rivermead Road, Iven          Gweru       Zimbabwe
# 145      Stand No. 436        436 Mtausi Park          Gweru       Zimbabwe
#
#     Applicant: Mailing Zip/Postal Code
# 141                             100021
# 142                             100187
# 143                             181300
# 144                                NaN
# 145                                263

# %%
new.shape
# Out:
# (146, 5)

# %%
new.head(10)
# Out:
#                                        MailingStreet  \
# 0     Road-4 House -621 Section -7 Mirpur Dhaka 1216
# 1               HOUSE-181-1-C, RAB3, BORO MOGHBAZAR,
# 2  2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,
# 3                       #63 Matikata, Matikata Bazar
# 4                      12/B SAYED AWLAD HOSSAIN LANE
# 5                                      P O BOX 70854
# 6  St.109 Sangkat Mittapheap Khan 7 Makara Phnom ...
# 7                                                O12
# 8                                         Quarter 03
# 9                              381 Yuanbin East Road
#
#            Mailing Street 2 MailingCity MailingCountry  \
# 0                       NaN       Dhaka     Bangladesh
# 1                       NaN       DHAKA     Bangladesh
# 2           Sarulia, Demra,       Dhaka     Bangladesh
# 3                       NaN       Dhaka     Bangladesh
# 4                  ISLAMPUR       DHAKA     Bangladesh
# ...

# %%
new.dropna(subset=["Applicant: Mailing Zip/Postal Code"], inplace=True)

# %%
new['MailingStreet']
# Out:
# 0         Road-4 House -621 Section -7 Mirpur Dhaka 1216
# 1                   HOUSE-181-1-C, RAB3, BORO MOGHBAZAR,
# 2      2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,
# 3                           #63 Matikata, Matikata Bazar
# 4                          12/B SAYED AWLAD HOSSAIN LANE
#                              ...
# 140                                       58 fountain st
# 141                                      S.Darboza 4b/71
# 142                                           uzbekistan
# 143                                    Khujakhurasan 4/1
# 145                                        Stand No. 436
# Name: MailingStreet, Length: 119, dtype: object

# %%
new['Mailing Street 2']
# Out:
# 0                        NaN
# 1                        NaN
# 2            Sarulia, Demra,
# 3                        NaN
# 4                   ISLAMPUR
#                ...
# 140                     #204
# 141    Shayhantohur district
# 142                      NaN
# 143                      NaN
# 145          436 Mtausi Park
# Name: Mailing Street 2, Length: 119, dtype: object

# %%
new['MailingCountry']
# Out:
# 0         Bangladesh
# 1         Bangladesh
# 2         Bangladesh
# 3         Bangladesh
# 4         Bangladesh
#            ...
# 140    United States
# 141       Uzbekistan
# 142       Uzbekistan
# 143       Uzbekistan
# 145         Zimbabwe
# Name: MailingCountry, Length: 119, dtype: object

# %%
new
# Out:
#                                          MailingStreet       Mailing Street 2  \
# 0       Road-4 House -621 Section -7 Mirpur Dhaka 1216                    NaN
# 1                 HOUSE-181-1-C, RAB3, BORO MOGHBAZAR,                    NaN
# 2    2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,        Sarulia, Demra,
# 3                         #63 Matikata, Matikata Bazar                    NaN
# 4                        12/B SAYED AWLAD HOSSAIN LANE               ISLAMPUR
# ..                                                 ...                    ...
# 140                                     58 fountain st                   #204
# 141                                    S.Darboza 4b/71  Shayhantohur district
# 142                                         uzbekistan                    NaN
# 143                                  Khujakhurasan 4/1                    NaN
# 145                                      Stand No. 436        436 Mtausi Park
#
# ...

# %%
new.drop_duplicates()
# Out:
#                                          MailingStreet       Mailing Street 2  \
# 0       Road-4 House -621 Section -7 Mirpur Dhaka 1216                    NaN
# 1                 HOUSE-181-1-C, RAB3, BORO MOGHBAZAR,                    NaN
# 2    2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,        Sarulia, Demra,
# 3                         #63 Matikata, Matikata Bazar                    NaN
# 4                        12/B SAYED AWLAD HOSSAIN LANE               ISLAMPUR
# ..                                                 ...                    ...
# 140                                     58 fountain st                   #204
# 141                                    S.Darboza 4b/71  Shayhantohur district
# 142                                         uzbekistan                    NaN
# 143                                  Khujakhurasan 4/1                    NaN
# 145                                      Stand No. 436        436 Mtausi Park
#
# ...

# %%
new.info
new.reset_index(drop=True, inplace=True)

# %%
new.to_csv("New Updated Address1")

# %%
import csv

# %%
with open(r"C:\Users\DELL\Desktop\New Updated Address1") as file_obj:
    reader_obj=csv.reader(file_obj)
    for row in reader_obj:
        print(row)
# Out:
# ['', 'MailingStreet', 'Mailing Street 2', 'MailingCity', 'MailingCountry', 'Applicant: Mailing Zip/Postal Code']
# ['0', '2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,', 'Sarulia, Demra,', 'Dhaka', 'Bangladesh', '1361,']
# ['1', '12/B SAYED AWLAD HOSSAIN LANE', 'ISLAMPUR', 'DHAKA', 'Bangladesh', '1100']
# ['2', 'O12', '12', 'DOUALA', 'Cameroon', '237']
# ['3', 'Quarter 03', 'Full Gospel Road Likomba', 'Tiko', 'Cameroon', '333 Tiko']
# ['4', '381 Yuanbin East Road', 'Xianyou County', 'Putian', 'China', '351200']
# ['5', 'Taiyuan University of Technology', 'No 79 West Yingze, Wanbailin District', 'Taiyuan', 'China', '30024']
# ['6', 'Ras Abebe Aregayi', 'Ras Abebe Aregay', 'Addis Ababa', 'Ethiopia', '9568']
# ['7', '2/1STATEMENT CLOSE. KOJOKROM.', 'POST OFFICE BX TD 832. TAKORADI.', 'SEKONDI', 'Ghana', '233']
# ['8', 'Digital address: Z227 Fork St, CX-082-5908', 'Fork St, Cx-082-590', 'Kasoa', 'Ghana', 'OK 39, KASOA']
# ...

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\New Updated Address1")
df
# Out:
#     Unnamed: 0                                      MailingStreet  \
# 0            0  2nd Floor, Hazi Nijam Uddin Tower, East Boxnogor,
# 1            1                      12/B SAYED AWLAD HOSSAIN LANE
# 2            2                                                O12
# 3            3                                         Quarter 03
# 4            4                              381 Yuanbin East Road
# 5            5                   Taiyuan University of Technology
# 6            6                                  Ras Abebe Aregayi
# 7            7                      2/1STATEMENT CLOSE. KOJOKROM.
# 8            8         Digital address: Z227 Fork St, CX-082-5908
# 9            9                                    Plot 20 Block P
# 10          10                                      Ongata Rongai
# 11          11                                     Johnson Street
# 12          12                                            Newroad
# ...

# %%
df["MailingStreet"]=df["MailingStreet"] + "," + df["Mailing Street 2"] +"," + df["MailingCity"] + "," + df["MailingCountry"]
df["MailingStreet"]
# Out:
# 0     2nd Floor, Hazi Nijam Uddin Tower, East Boxnog...
# 1     12/B SAYED AWLAD HOSSAIN LANE,ISLAMPUR,DHAKA,B...
# 2                                O12,12,DOUALA,Cameroon
# 3     Quarter 03,Full Gospel Road Likomba,Tiko,Cameroon
# 4     381 Yuanbin East Road,Xianyou County,Putian,China
# 5     Taiyuan University of Technology,No 79 West Yi...
# 6     Ras Abebe Aregayi,Ras Abebe Aregay,Addis Ababa...
# 7     2/1STATEMENT CLOSE. KOJOKROM.,POST OFFICE BX T...
# 8     Digital address: Z227 Fork St, CX-082-5908,For...
# 9                 Plot 20 Block P,Gyinyase,Kumasi,Ghana
# 10              Ongata Rongai,Bogani Road,Nairobi,Kenya
# 11              Johnson Street,Slipway,Monrovia,Liberia
# 12                          Newroad,Kaski,Pokhara,Nepal
# 13    2 Akinyele Close, Iju-Station,Agege, Lagos,2 A...
# 14       29 Adewale Adegbosin Street,Ajah,Lagos,Nigeria
# 15    Oba Elegushi Housing Estate Ilaje 6,Oba Elegus...
# 16            13,Oba Yekini Road,Elegushi Lekki,Nigeria
# ...

# %%
from geopy.geocoders import Nominatim
nom= Nominatim(user_agent="jupyter notebook")
n=nom.geocode("Dilshad Garden")

# %%
df["Validity"]=df["Mailing Street 2"]+"," +df["MailingCity"]
df["Validity"]
# Out:
# 0                                 Sarulia, Demra,,Dhaka
# 1                                        ISLAMPUR,DHAKA
# 2                                             12,DOUALA
# 3                         Full Gospel Road Likomba,Tiko
# 4                                 Xianyou County,Putian
# 5         No 79 West Yingze, Wanbailin District,Taiyuan
# 6                          Ras Abebe Aregay,Addis Ababa
# 7              POST OFFICE BX TD 832. TAKORADI.,SEKONDI
# 8                             Fork St, Cx-082-590,Kasoa
# 9                                       Gyinyase,Kumasi
# 10                                  Bogani Road,Nairobi
# 11                                     Slipway,Monrovia
# 12                                        Kaski,Pokhara
# 13    2 Akinyele Close, Iju-Station, Agege, Lagos,Lagos
# 14                                           Ajah,Lagos
# 15           Oba Elegushi Housing Estate, Ilaje, 6,Ajah
# 16                       Oba Yekini Road,Elegushi Lekki
# ...

# %%
df["Address"]=df["Validity"].apply(nom.geocode)
FinalAddress=df["Address"]

# %%
FinalAddress.to_csv("Valid_Address_csv")

# %%
valid=pd.read_csv(r"C:\Users\DELL\Desktop\Valid_Address_csv")
valid
# Out:
#     Unnamed: 0                                            Address
# 0            0                                                NaN
# 1            1  ইসলামপুর, ঢাকা, ঢাকা মহানগর, ঢাকা জেলা, ঢাকা ব...
# 2            2  Papa Douala, 12, Avenue Adolphe Demeur - Adolp...
# 3            3                                                NaN
# 4            4                                  仙游县, 莆田市, 福建省, 中国
# 5            5                                                NaN
# 6            6  Ras Abebe Aregay Street, ለገሐር አካባቢ / Legahar, ...
# 7            7                                                NaN
# 8            8                                                NaN
# 9            9  Kumasi High School, Gyinyase, Kumasi, Kumasi M...
# 10          10                 Bogani Road, Nairobi, 24722, Kenya
# 11          11  Slipway Road, Vai Town, Crown Hill, Monrovia, ...
# 12          12            Pokhara, कास्की, Gandaki Pradesh, नेपाल
# ...

# %%
valid.isnull().sum()
# Out:
# Unnamed: 0     0
# Address       22
# dtype: int64

# %%
valid.shape
# Out:
# (35, 2)
